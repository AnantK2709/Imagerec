# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16953, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 16953 (delta 74), reused 94 (delta 50), pack-reused 16805 (from 1)
# Receiving objects: 100% (16953/16953), 15.70 MiB | 6.87 MiB/s, done.
# Resolving deltas: 100% (11603/11603), done.
# /Users/anantkabra/Documents/GitHub/ImageRec/yolov5
# /Users/anantkabra/Library/Python/3.10/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.environ["DATASET _DIRECTORY"] = "/content/datasets"

# %% [markdown]
# ## Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "/content/drive/MyDrive/Mydataset.zip" "Mydataset.zip"

# %%
# !unzip -o /content/drive/MyDrive/Mydataset.zip -d /content/yolov5/Mydataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183343_jpg.rf.e1f285d51a9cf780186edac977c933ac.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183343_jpg.rf.f8c2d3bfd67b0c5a7fe44431e6314a5a.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.215cbc4fb0b5138bce411610e2d8aa7a.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.5617c778aa77b638c1494157886ac09b.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.6c539d679827d56e3e4a6c9a3455a5e8.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.70505bcc7964b17835b6f9e6a15cd3c0.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.72e95ed8f048e893fbe6e53e14a02a12.txt
#   inflating: /content/yolov5/Mydataset/train/labels/20210911_183344-0-_jpg.rf.a0d35ae5e24aa549991f68b4d432b95d.txt
# ...

# %% [markdown]
# ## Train the model

# %%
# !python train.py --img 416 --batch 16 --epochs 20 --data /content/yolov5/Mydataset/data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       18/19      2.02G    0.01006   0.002678   0.001728         23        416:  34% 509/1492 [02:52<04:43,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/19      2.02G    0.01006   0.002677   0.001728         22        416:  34% 510/1492 [02:52<04:18,  3.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/19      2.02G    0.01006   0.002678   0.001727         24        416:  34% 511/1492 [02:53<04:21,  3.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# # INFERENCE

# %%
import torch
# !python detect.py --weights best.pt --img 416 --conf 0.1 --source photo_2024-09-06_08-46-45.jpg
# Out:
# ^C

# %%
import glob
from IPython.display import Image, display
i = 0
# Choose the correct exp folder - see prev output block
for imageName in glob.glob('/content/yolov5/runs/detect/exp2/*.jpg'): #assuming JPG
  i += 1
  if i < 20:
    display (Image(filename=imageName))
    print("\n" )
    print("hoi")
# Out:
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
# hoi
